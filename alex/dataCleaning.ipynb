# %%
import datetime as dt
import numpy as np
import pandas as pd
import requests
import json
from pprint import pprint
import csv
import datetime
from pandas import Series

from flask import Flask, jsonify, render_template


from flask_sqlalchemy import SQLAlchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func
import sqlalchemy

# %%
engine = create_engine('sqlite:///./data/trade.sqlite')

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
session = Session(engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     327         """
# --> 328         return _ConnectionFairy._checkout(self)
#     329
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1228     def _do_get(self):
# -> 1229         return self._create_connection()
#    1230
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#
# OperationalError: unable to open database file
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-3-89ab6e2b16fd> in <module>()
#       1 Base = automap_base()
# ----> 2 Base.prepare(engine, reflect=True)
#       3 session = Session(engine)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\ext\automap.py in prepare(cls, engine, reflect, schema, classname_for_table, collection_class, name_for_scalar_relationship, name_for_collection_relationship, generate_relationship)
#     752                 schema=schema,
#     753                 extend_existing=True,
# --> 754                 autoload_replace=False
#     755             )
#     756
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\sql\schema.py in reflect(self, bind, schema, views, only, extend_existing, autoload_replace, **dialect_kwargs)
#    3853             bind = _bind_or_error(self)
#    3854
# -> 3855         with bind.connect() as conn:
#    3856
#    3857             reflect_opts = {
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in connect(self, **kwargs)
#    2089         """
#    2090
# -> 2091         return self._connection_cls(self, **kwargs)
#    2092
#    2093     def contextual_connect(self, close_with_result=False, **kwargs):
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    2175         """
#    2176         return self._wrap_pool_connect(
# -> 2177             self.pool.unique_connection, _connection)
#    2178
#    2179
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2149             if connection is None:
#    2150                 Connection._handle_dbapi_exception_noconnection(
# -> 2151                     e, dialect, self)
#    2152             else:
#    2153                 util.reraise(*sys.exc_info())
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1463             util.raise_from_cause(
#    1464                 sqlalchemy_exception,
# -> 1465                 exc_info
#    1466             )
#    1467         else:
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\util\compat.py in raise_from_cause(exception, exc_info)
#     201     exc_type, exc_value, exc_tb = exc_info
#     202     cause = exc_value if exc_value is not exception else None
# --> 203     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     204
#     205 if py3k:
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\util\compat.py in reraise(tp, value, tb, cause)
#     184             value.__cause__ = cause
#     185         if value.__traceback__ is not tb:
# --> 186             raise value.with_traceback(tb)
#     187         raise value
#     188
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    2145         dialect = self.dialect
#    2146         try:
# -> 2147             return fn()
#    2148         except dialect.dbapi.Error as e:
#    2149             if connection is None:
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in unique_connection(self)
#     326
#     327         """
# --> 328         return _ConnectionFairy._checkout(self)
#     329
#     330     def _create_connection(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _checkout(cls, pool, threadconns, fairy)
#     764     def _checkout(cls, pool, threadconns=None, fairy=None):
#     765         if not fairy:
# --> 766             fairy = _ConnectionRecord.checkout(pool)
#     767
#     768             fairy._pool = pool
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in checkout(cls, pool)
#     514     @classmethod
#     515     def checkout(cls, pool):
# --> 516         rec = pool._do_get()
#     517         try:
#     518             dbapi_connection = rec.get_connection()
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _do_get(self)
#    1227
#    1228     def _do_get(self):
# -> 1229         return self._create_connection()
#    1230
#    1231     def recreate(self):
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in _create_connection(self)
#     331         """Called by subclasses to create a new ConnectionRecord."""
#     332
# --> 333         return _ConnectionRecord(self)
#     334
#     335     def _invalidate(self, connection, exception=None):
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in __init__(self, pool, connect)
#     459         self.__pool = pool
#     460         if connect:
# --> 461             self.__connect(first_connect_check=True)
#     462         self.finalize_callback = deque()
#     463
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\pool.py in __connect(self, first_connect_check)
#     649         try:
#     650             self.starttime = time.time()
# --> 651             connection = pool._invoke_creator(self)
#     652             pool.logger.debug("Created new connection %r", connection)
#     653             self.connection = connection
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\strategies.py in connect(connection_record)
#     103                         if connection is not None:
#     104                             return connection
# --> 105                 return dialect.connect(*cargs, **cparams)
#     106
#     107             creator = pop_kwarg('creator', connect)
#
# ~\AppData\Roaming\Python\Python36\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     391
#     392     def connect(self, *cargs, **cparams):
# --> 393         return self.dbapi.connect(*cargs, **cparams)
#     394
#     395     def create_connect_args(self, url):
#
# OperationalError: (sqlite3.OperationalError) unable to open database file

# %%
Imports = Base.classes.imports

# %%
api_key = "93ba5366cb39b249dcbde95cc4d461e7b05b747d"
access_key = "4f9566c06802ac93dbb7af423e88dd45"
export_url = (f"https://api.census.gov/data/timeseries/intltrade/exports")
import_url = (f"https://api.census.gov/data/timeseries/intltrade/imports")
china_code = "5700"
usa_code = "1000"
month = []
year = []

# %%
total_import_by_commodity = requests.get(f"{import_url}/hs?get=CTY_CODE,CTY_NAME,I_COMMODITY,I_COMMODITY_SDESC,GEN_VAL_MO,GEN_VAL_YR&key={api_key}&time=from+2019-01&COMM_LVL=HS4").json()

# %%
count = 1
cty_code = []
cty_name = []
commodity = []
movalue = []
yrvalue = []
period = []
desc = []
code = []
while count < 3460904:
    count += 1
    cty_code.append(total_import_by_commodity[count][0])
    cty_name.append(total_import_by_commodity[count][1])
    commodity.append(total_import_by_commodity[count][2])
    desc.append(total_import_by_commodity[count][3])
    movalue.append(total_import_by_commodity[count][4])
    yrvalue.append(total_import_by_commodity[count][5])
    period.append(total_import_by_commodity[count][6])
total_import_commodity = pd.DataFrame({"YTDValue" : yrvalue,
                          "Period" : period,
                          "Description" : desc,
                          "HSC": commodity,
                          "MoValue" : movalue,
                           "Country" : cty_name,
                           "CountryCode": cty_code})

# %%
#total_import_commodity.to_sql('total_country_imports', con=engine, if_exists='update')

# %%
total_export_by_commodity = requests.get(f"{export_url}/hs?get=CTY_NAME,E_COMMODITY,E_COMMODITY_SDESC,ALL_VAL_MO&key={api_key}&time=from+2015-01&COMM_LVL=HS4").json()

# %%
len(total_export_by_commodity)
# Out:
# 617481

# %%
count = 1
cty_code = []
cty_name = []
commodity = []
movalue = []
yrvalue = []
period = []
desc = []
code = []
while count < 617480:
    count += 1
    cty_code.append(total_export_by_commodity[count][0])
    cty_name.append(total_export_by_commodity[count][1])
    commodity.append(total_export_by_commodity[count][2])
    desc.append(total_export_by_commodity[count][3])
    movalue.append(total_export_by_commodity[count][4])
    yrvalue.append(total_export_by_commodity[count][5])
    period.append(total_export_by_commodity[count][6])
total_export_commodity = pd.DataFrame({"YTDValue" : yrvalue,
                          "Period" : period,
                          "Description" : desc,
                          "HSC": commodity,
                          "MoValue" : movalue,
                           "Country" : cty_name,
                           "CountryCode": cty_code})

# %%
total_export_commodity.to_csv('total_country_exports', con=engine, index=False , if_exists='append')

# %%
results = session.query(Imports).statement
df = pd.read_sql_query(results, session.bind)

# %%
df = df.sort_values(by=["Period", "HSC"])

# %%
start_date = ""
end_date = ""
base = "USD"
symbols = ["USD","MXN","CNY","JPY","EUR","GBP","AUD","CHF","NZD"]
fx = requests.get(f"http://data.fixer.io/api/latest?access_key={access_key}&format=1").json()

# %%
series = pd.read_csv('allfx.csv')
X = series.values
train_size = int(len(X) * 0.66)
train, test = X[0:train_size], X[train_size:len(X)]
print('Observations: %d' % (len(X)))
print('Training Observations: %d' % (len(train)))
print('Testing Observations: %d' % (len(test)))

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-c42a15b2c7cf> in <module>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
country_df = df.groupby("Country")

# %%
country_df.sort_values("Country")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-ebdd522ca979> in <module>()
# ----> 1 country_df.sort_values("Country")
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\groupby\groupby.py in __getattr__(self, attr)
#     760             return self[attr]
#     761         if hasattr(self.obj, attr):
# --> 762             return self._make_wrapper(attr)
#     763
#     764         raise AttributeError("%r object has no attribute %r" %
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\groupby\groupby.py in _make_wrapper(self, name)
#     797                    "using the 'apply' method".format(kind, name,
#     798                                                      type(self).__name__))
# --> 799             raise AttributeError(msg)
#     800
#     801         self._set_group_selection()
#
# AttributeError: Cannot access callable attribute 'sort_values' of 'DataFrameGroupBy' objects, try using the 'apply' method

# %%
requests.get("http://api.apixu.com/v1/history.json?key=dc19bae6a35c47d8a0c165319190905&q=houston&dt=2015-01-01")
# Out:
# <Response [400]>

# %%
crude_data = pd.read_csv(f"https://s3.amazonaws.com/globefutures/data/CBOE_VX5.csv")

# %%
col_names = crude_data.columns

# %%
asx = pd.read_csv(f"https://s3.amazonaws.com/globefutures/data/ASX_AP1.csv")

# %%
asx.columns

# %%
crude_data.iloc(col_names[2])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-68da07d2774e> in <module>()
# ----> 1 crude_data.iloc(col_names[2])
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\indexing.py in __call__(self, axis)
#      96
#      97         if axis is not None:
# ---> 98             axis = self.obj._get_axis_number(axis)
#      99         new_self.axis = axis
#     100         return new_self
#
# ~\AppData\Roaming\Python\Python36\site-packages\pandas\core\generic.py in _get_axis_number(self, axis)
#     373                 pass
#     374         raise ValueError('No axis named {0} for object type {1}'
# --> 375                          .format(axis, type(self)))
#     376
#     377     def _get_axis_name(self, axis):
#
# ValueError: No axis named Open for object type <class 'pandas.core.frame.DataFrame'>

# %%
import os
data_dir = "C://Users/alexb/Documents/class/project3data/dump"
merged_data = pd.DataFrame()
length = len(os.listdir(data_dir))
for filename in os.listdir(data_dir):
    print(filename)
    dataset=pd.read_csv(os.path.join(data_dir, filename))
    col_names = dataset.columns
    
    merged_data = merged_data.append(dataset_mean_abs)

# merged_data.columns = ['Bearing 1','Bearing 2','Bearing 3','Bearing 4']
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-108-a25895ce0a40> in <module>()
#       1 data_dir = '"https://s3.amazonaws.com/globefutures/data/'
#       2 merged_data = pd.DataFrame()
# ----> 3 length = len(os.listdir(data_dir))
#       4 for filename in os.listdir(data_dir):
#       5     print(filename)
#
# OSError: [WinError 123] The filename, directory name, or volume label syntax is incorrect: '"https://s3.amazonaws.com/globefutures/data/'

# %%
http://localhost:8888/lab/tree/Documents%2Fclass%2Fproject3data%2Fdump

# %%
# Out:
# ['ASX_AP1.csv',
#  'ASX_AP2.csv',
#  'ASX_BB1.csv',
#  'ASX_BB2.csv',
#  'ASX_IB1.csv',
#  'ASX_IB2.csv',
#  'ASX_IR1.csv',
#  'ASX_IR2.csv',
#  'ASX_TN1.csv',
#  'ASX_TN2.csv',
#  'ASX_TY1.csv',
#  'ASX_TY2.csv',
#  'ASX_UB1.csv',
#  'ASX_UB2.csv',
#  'ASX_UB3.csv',
#  'ASX_UB4.csv',
#  'ASX_UB5.csv',
#  'ASX_UB6.csv',
#  'ASX_UB7.csv',
#  'ASX_US1.csv',
#  'ASX_US2.csv',
#  'ASX_US3.csv',
#  'ASX_US4.csv',
#  'ASX_US5.csv',
#  'ASX_US6.csv',
#  'ASX_VC1.csv',
#  'ASX_VC2.csv',
#  'ASX_VC3.csv',
#  'ASX_VC4.csv',
#  'ASX_VC5.csv',
#  'ASX_VC6.csv',
#  'ASX_VW1.csv',
#  'ASX_VW2.csv',
#  'ASX_VW3.csv',
#  'ASX_VW4.csv',
#  'ASX_VW5.csv',
#  'ASX_VW6.csv',
#  'ASX_WK1.csv',
#  'ASX_WK2.csv',
#  'ASX_WK3.csv',
#  'ASX_WK4.csv',
#  'ASX_WK5.csv',
#  'ASX_WK6.csv',
#  'ASX_WM1.csv',
#  'ASX_WM2.csv',
#  'ASX_WM3.csv',
#  'ASX_WM4.csv',
#  'ASX_WM5.csv',
#  'ASX_XS1.csv',
#  'ASX_XS2.csv',
#  'ASX_XT1.csv',
#  'ASX_XT2.csv',
#  'ASX_YS1.csv',
#  'ASX_YS2.csv',
#  'ASX_YT1.csv',
#  'ASX_YT2.csv',
#  'CBOE_GV1.csv',
#  'CBOE_GV2.csv',
#  'CBOE_OV1.csv',
#  'CBOE_OV2.csv',
#  'CBOE_VN1.csv',
#  'CBOE_VN2.csv',
#  'CBOE_VX1.csv',
#  'CBOE_VX2.csv',
#  'CBOE_VX3.csv',
#  'CBOE_VX4.csv',
#  'CBOE_VX5.csv',
#  'CBOE_VX6.csv',
#  'CBOE_VX7.csv',
#  'CBOE_VX8.csv',
#  'CBOE_VX9.csv',
#  'CBOE_VXEW1.csv',
#  'CBOE_VXEW2.csv',
#  'CHRIS_metadata.csv',
#  'CME_0D1.csv',
#  'CME_0D2.csv',
#  'CME_0D3.csv',
#  'CME_0D4.csv',
#  'CME_0D5.csv',
#  'CME_0F1.csv',
#  'CME_0F2.csv',
#  'CME_1N1.csv',
#  'CME_1N2.csv',
#  'CME_1N3.csv',
#  'CME_1N4.csv',
#  'CME_1NB1.csv',
#  'CME_1NB2.csv',
#  'CME_1NB3.csv',
#  'CME_1NB4.csv',
#  'CME_1R1.csv',
#  'CME_1R2.csv',
#  'CME_1U1.csv',
#  'CME_1U2.csv',
#  'CME_1U3.csv',
#  'CME_1U4.csv',
#  'CME_461.csv',
#  'CME_4610.csv',
#  'CME_4611.csv',
#  'CME_4612.csv',
#  'CME_462.csv',
#  'CME_463.csv',
#  'CME_464.csv',
#  'CME_465.csv',
#  'CME_466.csv',
#  'CME_467.csv',
#  'CME_468.csv',
#  'CME_469.csv',
#  'CME_471.csv',
#  'CME_472.csv',
#  'CME_4L1.csv',
#  'CME_4L2.csv',
#  'CME_4M1.csv',
#  'CME_4M10.csv',
#  'CME_4M2.csv',
#  'CME_4M3.csv',
#  'CME_4M4.csv',
#  'CME_4M5.csv',
#  'CME_4M6.csv',
#  'CME_4M7.csv',
#  'CME_4M8.csv',
#  'CME_4M9.csv',
#  'CME_4N1.csv',
#  'CME_4N2.csv',
#  'CME_4P1.csv',
#  'CME_4P10.csv',
#  'CME_4P11.csv',
#  'CME_4P12.csv',
#  'CME_4P13.csv',
#  'CME_4P14.csv',
#  'CME_4P15.csv',
#  'CME_4P16.csv',
#  'CME_4P2.csv',
#  'CME_4P3.csv',
#  'CME_4P4.csv',
#  'CME_4P5.csv',
#  'CME_4P6.csv',
#  'CME_4P7.csv',
#  'CME_4P8.csv',
#  'CME_4P9.csv',
#  'CME_581.csv',
#  'CME_5810.csv',
#  'CME_5811.csv',
#  'CME_5812.csv',
#  'CME_582.csv',
#  'CME_583.csv',
#  'CME_584.csv',
#  'CME_585.csv',
#  'CME_586.csv',
#  'CME_587.csv',
#  'CME_588.csv',
#  'CME_589.csv',
#  'CME_5C1.csv',
#  'CME_5C2.csv',
#  'CME_5Z1.csv',
#  'CME_5Z2.csv',
#  'CME_5Z3.csv',
#  'CME_5Z4.csv',
#  'CME_5Z5.csv',
#  'CME_5Z6.csv',
#  'CME_5Z7.csv',
#  'CME_5Z8.csv',
#  'CME_5Z9.csv',
#  'CME_6T1.csv',
#  'CME_6T2.csv',
#  'CME_6T3.csv',
#  'CME_6T4.csv',
#  'CME_6T5.csv',
#  'CME_6T6.csv',
#  'CME_6Z1.csv',
#  'CME_6Z2.csv',
#  'CME_711.csv',
#  'CME_712.csv',
#  'CME_7H1.csv',
#  'CME_7H2.csv',
#  'CME_7H3.csv',
#  'CME_7H4.csv',
#  'CME_7H5.csv',
#  'CME_7K1.csv',
#  'CME_7K10.csv',
#  'CME_7K2.csv',
#  'CME_7K3.csv',
#  'CME_7K4.csv',
#  'CME_7K5.csv',
#  'CME_7K6.csv',
#  'CME_7K7.csv',
#  'CME_7K8.csv',
#  'CME_7K9.csv',
#  'CME_7Q1.csv',
#  'CME_7Q2.csv',
#  'CME_7Q3.csv',
#  'CME_7Y1.csv',
#  'CME_7Y2.csv',
#  'CME_8I1.csv',
#  'CME_8I2.csv',
#  'CME_8Z1.csv',
#  'CME_8Z2.csv',
#  'CME_9F1.csv',
#  'CME_9F2.csv',
#  'CME_A31.csv',
#  'CME_A310.csv',
#  'CME_A311.csv',
#  'CME_A312.csv',
#  'CME_A313.csv',
#  'CME_A314.csv',
#  'CME_A315.csv',
#  'CME_A316.csv',
#  'CME_A317.csv',
#  'CME_A318.csv',
#  'CME_A319.csv',
#  'CME_A32.csv',
#  'CME_A320.csv',
#  'CME_A321.csv',
#  'CME_A322.csv',
#  'CME_A323.csv',
#  'CME_A324.csv',
#  'CME_A325.csv',
#  'CME_A326.csv',
#  'CME_A327.csv',
#  'CME_A328.csv',
#  'CME_A329.csv',
#  'CME_A33.csv',
#  'CME_A330.csv',
#  'CME_A331.csv',
#  'CME_A332.csv',
#  'CME_A333.csv',
#  'CME_A334.csv',
#  'CME_A34.csv',
#  'CME_A35.csv',
#  'CME_A36.csv',
#  'CME_A37.csv',
#  'CME_A38.csv',
#  'CME_A39.csv',
#  'CME_A51.csv',
#  'CME_A52.csv',
#  'CME_A61.csv',
#  'CME_A610.csv',
#  'CME_A62.csv',
#  'CME_A63.csv',
#  'CME_A64.csv',
#  'CME_A65.csv',
#  'CME_A66.csv',
#  'CME_A67.csv',
#  'CME_A68.csv',
#  'CME_A69.csv',
#  'CME_ABY1.csv',
#  'CME_ABY2.csv',
#  'CME_ABY3.csv',
#  'CME_ABY4.csv',
#  'CME_AD1.csv',
#  'CME_AD2.csv',
#  'CME_AFF1.csv',
#  'CME_AFF10.csv',
#  'CME_AFF2.csv',
#  'CME_AFF3.csv',
#  'CME_AFF4.csv',
#  'CME_AFF5.csv',
#  'CME_AFF6.csv',
#  'CME_AFF7.csv',
#  'CME_AFF8.csv',
#  'CME_AFF9.csv',
#  'CME_AGA1.csv',
#  'CME_AGA10.csv',
#  'CME_AGA2.csv',
#  'CME_AGA3.csv',
#  'CME_AGA4.csv',
#  'CME_AGA5.csv',
#  'CME_AGA6.csv',
#  'CME_AGA7.csv',
#  'CME_AGA8.csv',
#  'CME_AGA9.csv',
#  'CME_ALI1.csv',
#  'CME_ALI2.csv',
#  'CME_ARW1.csv',
#  'CME_ARW2.csv',
#  'CME_AW1.csv',
#  'CME_AW2.csv',
#  'CME_B01.csv',
#  'CME_B010.csv',
#  'CME_B011.csv',
#  'CME_B02.csv',
#  'CME_B03.csv',
#  'CME_B04.csv',
#  'CME_B05.csv',
#  'CME_B06.csv',
#  'CME_B07.csv',
#  'CME_B08.csv',
#  'CME_B09.csv',
#  'CME_B31.csv',
#  'CME_B310.csv',
#  'CME_B311.csv',
#  'CME_B312.csv',
#  'CME_B313.csv',
#  'CME_B314.csv',
#  'CME_B315.csv',
#  'CME_B316.csv',
#  'CME_B317.csv',
#  'CME_B318.csv',
#  'CME_B319.csv',
#  'CME_B32.csv',
#  'CME_B320.csv',
#  'CME_B321.csv',
#  'CME_B322.csv',
#  'CME_B323.csv',
#  'CME_B324.csv',
#  'CME_B325.csv',
#  'CME_B326.csv',
#  'CME_B327.csv',
#  'CME_B328.csv',
#  'CME_B329.csv',
#  'CME_B33.csv',
#  'CME_B330.csv',
#  'CME_B34.csv',
#  'CME_B35.csv',
#  'CME_B36.csv',
#  'CME_B37.csv',
#  'CME_B38.csv',
#  'CME_B39.csv',
#  'CME_B41.csv',
#  'CME_B42.csv',
#  'CME_B43.csv',
#  'CME_B44.csv',
#  'CME_B45.csv',
#  'CME_B46.csv',
#  'CME_B47.csv',
#  'CME_B61.csv',
#  'CME_B610.csv',
#  'CME_B611.csv',
#  'CME_B612.csv',
#  'CME_B613.csv',
#  'CME_B614.csv',
#  'CME_B615.csv',
#  'CME_B616.csv',
#  'CME_B617.csv',
#  'CME_B618.csv',
#  'CME_B619.csv',
#  'CME_B62.csv',
#  'CME_B620.csv',
#  'CME_B621.csv',
#  'CME_B622.csv',
#  'CME_B623.csv',
#  'CME_B624.csv',
#  'CME_B625.csv',
#  'CME_B626.csv',
#  'CME_B627.csv',
#  'CME_B628.csv',
#  'CME_B629.csv',
#  'CME_B63.csv',
#  'CME_B630.csv',
#  'CME_B631.csv',
#  'CME_B632.csv',
#  'CME_B633.csv',
#  'CME_B634.csv',
#  'CME_B64.csv',
#  'CME_B65.csv',
#  'CME_B66.csv',
#  'CME_B67.csv',
#  'CME_B68.csv',
#  'CME_B69.csv',
#  'CME_BB1.csv',
#  'CME_BB2.csv',
#  'CME_BB3.csv',
#  'CME_BB4.csv',
#  'CME_BB5.csv',
#  'CME_BK1.csv',
#  'CME_BK10.csv',
#  'CME_BK11.csv',
#  'CME_BK12.csv',
#  'CME_BK13.csv',
#  'CME_BK14.csv',
#  'CME_BK15.csv',
#  'CME_BK16.csv',
#  'CME_BK17.csv',
#  'CME_BK18.csv',
#  'CME_BK19.csv',
#  'CME_BK2.csv',
#  'CME_BK20.csv',
#  'CME_BK21.csv',
#  'CME_BK22.csv',
#  'CME_BK23.csv',
#  'CME_BK24.csv',
#  'CME_BK25.csv',
#  'CME_BK26.csv',
#  'CME_BK27.csv',
#  'CME_BK28.csv',
#  'CME_BK29.csv',
#  'CME_BK3.csv',
#  'CME_BK30.csv',
#  'CME_BK31.csv',
#  'CME_BK32.csv',
#  'CME_BK33.csv',
#  'CME_BK34.csv',
#  'CME_BK4.csv',
#  'CME_BK5.csv',
#  'CME_BK6.csv',
#  'CME_BK7.csv',
#  'CME_BK8.csv',
#  'CME_BK9.csv',
#  'CME_BO1.csv',
#  'CME_BO10.csv',
#  'CME_BO2.csv',
#  'CME_BO3.csv',
#  'CME_BO4.csv',
#  'CME_BO5.csv',
#  'CME_BO6.csv',
#  'CME_BO7.csv',
#  'CME_BO8.csv',
#  'CME_BO9.csv',
#  'CME_BOB1.csv',
#  'CME_BOB2.csv',
#  'CME_BP1.csv',
#  'CME_BP2.csv',
#  'CME_BR1.csv',
#  'CME_BR2.csv',
#  'CME_BR3.csv',
#  'CME_BR4.csv',
#  'CME_BY1.csv',
#  'CME_BY2.csv',
#  'CME_BZ1.csv',
#  'CME_BZ10.csv',
#  'CME_BZ11.csv',
#  'CME_BZ12.csv',
#  'CME_BZ13.csv',
#  'CME_BZ14.csv',
#  'CME_BZ15.csv',
#  'CME_BZ16.csv',
#  'CME_BZ2.csv',
#  'CME_BZ3.csv',
#  'CME_BZ4.csv',
#  'CME_BZ5.csv',
#  'CME_BZ6.csv',
#  'CME_BZ7.csv',
#  'CME_BZ8.csv',
#  'CME_BZ9.csv',
#  'CME_C01.csv',
#  'CME_C010.csv',
#  'CME_C02.csv',
#  'CME_C03.csv',
#  'CME_C04.csv',
#  'CME_C05.csv',
#  'CME_C06.csv',
#  'CME_C07.csv',
#  'CME_C08.csv',
#  'CME_C09.csv',
#  'CME_C1.csv',
#  'CME_C10.csv',
#  'CME_C2.csv',
#  'CME_C3.csv',
#  'CME_C4.csv',
#  'CME_C5.csv',
#  'CME_C6.csv',
#  'CME_C7.csv',
#  'CME_C8.csv',
#  'CME_C9.csv',
#  'CME_CB1.csv',
#  'CME_CB10.csv',
#  'CME_CB11.csv',
#  'CME_CB12.csv',
#  'CME_CB13.csv',
#  'CME_CB14.csv',
#  'CME_CB15.csv',
#  'CME_CB16.csv',
#  'CME_CB17.csv',
#  'CME_CB18.csv',
#  'CME_CB19.csv',
#  'CME_CB2.csv',
#  'CME_CB20.csv',
#  'CME_CB3.csv',
#  'CME_CB4.csv',
#  'CME_CB5.csv',
#  'CME_CB6.csv',
#  'CME_CB7.csv',
#  'CME_CB8.csv',
#  'CME_CB9.csv',
#  'CME_CD1.csv',
#  'CME_CD2.csv',
#  'CME_CD3.csv',
#  'CME_CD4.csv',
#  'CME_CI1.csv',
#  'CME_CI2.csv',
#  'CME_CL1.csv',
#  'CME_CL10.csv',
#  'CME_CL11.csv',
#  'CME_CL12.csv',
#  'CME_CL13.csv',
#  'CME_CL14.csv',
#  'CME_CL15.csv',
#  'CME_CL16.csv',
#  'CME_CL17.csv',
#  'CME_CL18.csv',
#  'CME_CL19.csv',
#  'CME_CL2.csv',
#  'CME_CL20.csv',
#  'CME_CL21.csv',
#  'CME_CL22.csv',
#  'CME_CL23.csv',
#  'CME_CL24.csv',
#  'CME_CL25.csv',
#  'CME_CL26.csv',
#  'CME_CL27.csv',
#  'CME_CL28.csv',
#  'CME_CL29.csv',
#  'CME_CL3.csv',
#  'CME_CL30.csv',
#  'CME_CL31.csv',
#  'CME_CL32.csv',
#  'CME_CL33.csv',
#  'CME_CL34.csv',
#  'CME_CL35.csv',
#  'CME_CL36.csv',
#  'CME_CL37.csv',
#  'CME_CL38.csv',
#  'CME_CL4.csv',
#  'CME_CL5.csv',
#  'CME_CL6.csv',
#  'CME_CL7.csv',
#  'CME_CL8.csv',
#  'CME_CL9.csv',
#  'CME_CNH1.csv',
#  'CME_CNH2.csv',
#  'CME_CPO1.csv',
#  'CME_CPO2.csv',
#  'CME_CPO3.csv',
#  'CME_CPO4.csv',
#  'CME_CPO5.csv',
#  'CME_CPO6.csv',
#  'CME_CPO7.csv',
#  'CME_CPO8.csv',
#  'CME_CS1.csv',
#  'CME_CS10.csv',
#  'CME_CS11.csv',
#  'CME_CS12.csv',
#  'CME_CS13.csv',
#  'CME_CS14.csv',
#  'CME_CS15.csv',
#  'CME_CS16.csv',
#  'CME_CS17.csv',
#  'CME_CS18.csv',
#  'CME_CS19.csv',
#  'CME_CS2.csv',
#  'CME_CS20.csv',
#  'CME_CS21.csv',
#  'CME_CS22.csv',
#  'CME_CS23.csv',
#  'CME_CS24.csv',
#  'CME_CS25.csv',
#  'CME_CS26.csv',
#  'CME_CS27.csv',
#  'CME_CS28.csv',
#  'CME_CS29.csv',
#  'CME_CS3.csv',
#  'CME_CS30.csv',
#  'CME_CS31.csv',
#  'CME_CS32.csv',
#  'CME_CS33.csv',
#  'CME_CS34.csv',
#  'CME_CS4.csv',
#  'CME_CS5.csv',
#  'CME_CS6.csv',
#  'CME_CS7.csv',
#  'CME_CS8.csv',
#  'CME_CS9.csv',
#  'CME_CSC1.csv',
#  'CME_CSC10.csv',
#  'CME_CSC2.csv',
#  'CME_CSC3.csv',
#  'CME_CSC4.csv',
#  'CME_CSC5.csv',
#  'CME_CSC6.csv',
#  'CME_CSC7.csv',
#  'CME_CSC8.csv',
#  'CME_CSC9.csv',
#  'CME_CU1.csv',
#  'CME_CU10.csv',
#  'CME_CU11.csv',
#  'CME_CU12.csv',
#  'CME_CU13.csv',
#  'CME_CU2.csv',
#  'CME_CU3.csv',
#  'CME_CU4.csv',
#  'CME_CU5.csv',
#  'CME_CU6.csv',
#  'CME_CU7.csv',
#  'CME_CU8.csv',
#  'CME_CU9.csv',
#  'CME_CY1.csv',
#  'CME_CY10.csv',
#  'CME_CY11.csv',
#  'CME_CY12.csv',
#  'CME_CY13.csv',
#  'CME_CY14.csv',
#  'CME_CY15.csv',
#  'CME_CY16.csv',
#  'CME_CY17.csv',
#  'CME_CY18.csv',
#  'CME_CY19.csv',
#  'CME_CY2.csv',
#  'CME_CY20.csv',
#  'CME_CY21.csv',
#  'CME_CY22.csv',
#  'CME_CY3.csv',
#  'CME_CY4.csv',
#  'CME_CY5.csv',
#  'CME_CY6.csv',
#  'CME_CY7.csv',
#  'CME_CY8.csv',
#  'CME_CY9.csv',
#  'CME_CZ1.csv',
#  'CME_CZ2.csv',
#  'CME_D01.csv',
#  'CME_D010.csv',
#  'CME_D02.csv',
#  'CME_D03.csv',
#  'CME_D04.csv',
#  'CME_D05.csv',
#  'CME_D06.csv',
#  'CME_D07.csv',
#  'CME_D08.csv',
#  'CME_D09.csv',
#  'CME_D21.csv',
#  'CME_D210.csv',
#  'CME_D211.csv',
#  'CME_D212.csv',
#  'CME_D213.csv',
#  'CME_D214.csv',
#  'CME_D215.csv',
#  'CME_D216.csv',
#  'CME_D217.csv',
#  'CME_D218.csv',
#  'CME_D219.csv',
#  'CME_D22.csv',
#  'CME_D220.csv',
#  'CME_D221.csv',
#  'CME_D222.csv',
#  'CME_D223.csv',
#  'CME_D224.csv',
#  'CME_D225.csv',
#  'CME_D226.csv',
#  'CME_D227.csv',
#  'CME_D228.csv',
#  'CME_D229.csv',
#  'CME_D23.csv',
#  'CME_D230.csv',
#  'CME_D231.csv',
#  'CME_D232.csv',
#  'CME_D233.csv',
#  'CME_D234.csv',
#  'CME_D24.csv',
#  'CME_D25.csv',
#  'CME_D26.csv',
#  'CME_D27.csv',
#  'CME_D28.csv',
#  'CME_D29.csv',
#  'CME_D31.csv',
#  'CME_D310.csv',
#  'CME_D32.csv',
#  'CME_D33.csv',
#  'CME_D34.csv',
#  'CME_D35.csv',
#  'CME_D36.csv',
#  'CME_D37.csv',
#  'CME_D38.csv',
#  'CME_D39.csv',
#  'CME_D41.csv',
#  'CME_D410.csv',
#  'CME_D411.csv',
#  'CME_D412.csv',
#  'CME_D413.csv',
#  'CME_D414.csv',
#  'CME_D415.csv',
#  'CME_D416.csv',
#  'CME_D417.csv',
#  'CME_D418.csv',
#  'CME_D419.csv',
#  'CME_D42.csv',
#  'CME_D420.csv',
#  'CME_D421.csv',
#  'CME_D422.csv',
#  'CME_D423.csv',
#  'CME_D424.csv',
#  'CME_D425.csv',
#  'CME_D426.csv',
#  'CME_D427.csv',
#  'CME_D428.csv',
#  'CME_D429.csv',
#  'CME_D43.csv',
#  'CME_D430.csv',
#  'CME_D431.csv',
#  'CME_D432.csv',
#  'CME_D433.csv',
#  'CME_D434.csv',
#  'CME_D44.csv',
#  'CME_D45.csv',
#  'CME_D46.csv',
#  'CME_D47.csv',
#  'CME_D48.csv',
#  'CME_D49.csv',
#  'CME_D61.csv',
#  'CME_D62.csv',
#  'CME_D71.csv',
#  'CME_D710.csv',
#  'CME_D711.csv',
#  'CME_D712.csv',
#  'CME_D713.csv',
#  'CME_D714.csv',
#  'CME_D715.csv',
#  'CME_D716.csv',
#  'CME_D717.csv',
#  'CME_D718.csv',
#  'CME_D719.csv',
#  'CME_D72.csv',
#  'CME_D720.csv',
#  'CME_D721.csv',
#  'CME_D722.csv',
#  'CME_D73.csv',
#  'CME_D74.csv',
#  'CME_D75.csv',
#  'CME_D76.csv',
#  'CME_D77.csv',
#  'CME_D78.csv',
#  'CME_D79.csv',
#  'CME_D81.csv',
#  'CME_D82.csv',
#  'CME_D91.csv',
#  'CME_D910.csv',
#  'CME_D911.csv',
#  'CME_D912.csv',
#  'CME_D913.csv',
#  'CME_D914.csv',
#  'CME_D915.csv',
#  'CME_D916.csv',
#  'CME_D917.csv',
#  'CME_D918.csv',
#  'CME_D919.csv',
#  'CME_D92.csv',
#  'CME_D920.csv',
#  'CME_D921.csv',
#  'CME_D922.csv',
#  'CME_D93.csv',
#  'CME_D94.csv',
#  'CME_D95.csv',
#  'CME_D96.csv',
#  'CME_D97.csv',
#  'CME_D98.csv',
#  'CME_D99.csv',
#  'CME_DA1.csv',
#  'CME_DA10.csv',
#  'CME_DA2.csv',
#  'CME_DA3.csv',
#  'CME_DA4.csv',
#  'CME_DA5.csv',
#  'CME_DA6.csv',
#  'CME_DA7.csv',
#  'CME_DA8.csv',
#  'CME_DA9.csv',
#  'CME_DB1.csv',
#  'CME_DB2.csv',
#  'CME_DC1.csv',
#  'CME_DC2.csv',
#  'CME_DJ1.csv',
#  'CME_DJ2.csv',
#  'CME_DK1.csv',
#  'CME_DK10.csv',
#  'CME_DK11.csv',
#  'CME_DK12.csv',
#  'CME_DK2.csv',
#  'CME_DK3.csv',
#  'CME_DK4.csv',
#  'CME_DK5.csv',
#  'CME_DK6.csv',
#  'CME_DK7.csv',
#  'CME_DK8.csv',
#  'CME_DK9.csv',
#  'CME_DY1.csv',
#  'CME_DY10.csv',
#  'CME_DY11.csv',
#  'CME_DY12.csv',
#  'CME_DY13.csv',
#  'CME_DY14.csv',
#  'CME_DY15.csv',
#  'CME_DY16.csv',
#  'CME_DY17.csv',
#  'CME_DY18.csv',
#  'CME_DY19.csv',
#  'CME_DY2.csv',
#  'CME_DY20.csv',
#  'CME_DY3.csv',
#  'CME_DY4.csv',
#  'CME_DY5.csv',
#  'CME_DY6.csv',
#  'CME_DY7.csv',
#  'CME_DY8.csv',
#  'CME_DY9.csv',
#  'CME_E31.csv',
#  'CME_E32.csv',
#  'CME_E41.csv',
#  'CME_E410.csv',
#  'CME_E411.csv',
#  'CME_E412.csv',
#  'CME_E413.csv',
#  'CME_E414.csv',
#  'CME_E415.csv',
#  'CME_E416.csv',
#  'CME_E417.csv',
#  'CME_E418.csv',
#  'CME_E419.csv',
#  'CME_E42.csv',
#  'CME_E420.csv',
#  'CME_E421.csv',
#  'CME_E422.csv',
#  'CME_E423.csv',
#  'CME_E424.csv',
#  'CME_E425.csv',
#  'CME_E426.csv',
#  'CME_E427.csv',
#  'CME_E428.csv',
#  'CME_E429.csv',
#  'CME_E43.csv',
#  'CME_E430.csv',
#  'CME_E431.csv',
#  'CME_E432.csv',
#  'CME_E433.csv',
#  'CME_E434.csv',
#  'CME_E435.csv',
#  'CME_E436.csv',
#  'CME_E437.csv',
#  'CME_E438.csv',
#  'CME_E439.csv',
#  'CME_E44.csv',
#  'CME_E440.csv',
#  'CME_E441.csv',
#  'CME_E442.csv',
#  'CME_E443.csv',
#  'CME_E444.csv',
#  'CME_E445.csv',
#  'CME_E446.csv',
#  'CME_E447.csv',
#  'CME_E448.csv',
#  'CME_E449.csv',
#  'CME_E45.csv',
#  'CME_E450.csv',
#  'CME_E451.csv',
#  'CME_E46.csv',
#  'CME_E47.csv',
#  'CME_E48.csv',
#  'CME_E49.csv',
#  'CME_E51.csv',
#  'CME_E52.csv',
#  'CME_E71.csv',
#  'CME_E72.csv',
#  'CME_E81.csv',
#  'CME_E82.csv',
#  'CME_E83.csv',
#  'CME_EC1.csv',
#  'CME_EC2.csv',
#  'CME_ED1.csv',
#  'CME_ED10.csv',
#  'CME_ED11.csv',
#  'CME_ED12.csv',
#  'CME_ED13.csv',
#  'CME_ED14.csv',
#  'CME_ED15.csv',
#  'CME_ED16.csv',
#  'CME_ED17.csv',
#  'CME_ED18.csv',
#  'CME_ED19.csv',
#  'CME_ED2.csv',
#  'CME_ED20.csv',
#  'CME_ED21.csv',
#  'CME_ED22.csv',
#  'CME_ED23.csv',
#  'CME_ED24.csv',
#  'CME_ED25.csv',
#  'CME_ED26.csv',
#  'CME_ED27.csv',
#  'CME_ED28.csv',
#  'CME_ED29.csv',
#  'CME_ED3.csv',
#  'CME_ED30.csv',
#  'CME_ED31.csv',
#  'CME_ED32.csv',
#  'CME_ED33.csv',
#  'CME_ED34.csv',
#  'CME_ED35.csv',
#  'CME_ED36.csv',
#  'CME_ED37.csv',
#  'CME_ED4.csv',
#  'CME_ED5.csv',
#  'CME_ED6.csv',
#  'CME_ED7.csv',
#  'CME_ED8.csv',
#  'CME_ED9.csv',
#  'CME_EH1.csv',
#  'CME_EH2.csv',
#  'CME_EH3.csv',
#  'CME_EH4.csv',
#  'CME_EJ1.csv',
#  'CME_EJ2.csv',
#  'CME_EM1.csv',
#  'CME_EM2.csv',
#  'CME_EM3.csv',
#  'CME_EN1.csv',
#  'CME_EN10.csv',
#  'CME_EN2.csv',
#  'CME_EN3.csv',
#  'CME_EN4.csv',
#  'CME_EN5.csv',
#  'CME_EN6.csv',
#  'CME_EN7.csv',
#  'CME_EN8.csv',
#  'CME_EN9.csv',
#  'CME_ES1.csv',
#  'CME_ES2.csv',
#  'CME_ES3.csv',
#  'CME_ES4.csv',
#  'CME_EW1.csv',
#  'CME_EW2.csv',
#  'CME_EY1.csv',
#  'CME_EY2.csv',
#  'CME_F21.csv',
#  'CME_F210.csv',
#  'CME_F211.csv',
#  'CME_F212.csv',
#  'CME_F213.csv',
#  'CME_F214.csv',
#  'CME_F215.csv',
#  'CME_F216.csv',
#  'CME_F217.csv',
#  'CME_F218.csv',
#  'CME_F219.csv',
#  'CME_F22.csv',
#  'CME_F220.csv',
#  'CME_F221.csv',
#  'CME_F222.csv',
#  'CME_F223.csv',
#  'CME_F224.csv',
#  'CME_F225.csv',
#  'CME_F226.csv',
#  'CME_F227.csv',
#  'CME_F228.csv',
#  'CME_F229.csv',
#  'CME_F23.csv',
#  'CME_F230.csv',
#  'CME_F231.csv',
#  'CME_F232.csv',
#  'CME_F233.csv',
#  'CME_F234.csv',
#  'CME_F235.csv',
#  'CME_F236.csv',
#  'CME_F237.csv',
#  'CME_F238.csv',
#  'CME_F239.csv',
#  'CME_F24.csv',
#  'CME_F25.csv',
#  'CME_F26.csv',
#  'CME_F27.csv',
#  'CME_F28.csv',
#  'CME_F29.csv',
#  'CME_F51.csv',
#  'CME_F510.csv',
#  'CME_F511.csv',
#  'CME_F512.csv',
#  'CME_F513.csv',
#  'CME_F514.csv',
#  'CME_F515.csv',
#  'CME_F516.csv',
#  'CME_F517.csv',
#  'CME_F518.csv',
#  'CME_F519.csv',
#  'CME_F52.csv',
#  'CME_F520.csv',
#  'CME_F521.csv',
#  'CME_F522.csv',
#  'CME_F53.csv',
#  'CME_F54.csv',
#  'CME_F55.csv',
#  'CME_F56.csv',
#  'CME_F57.csv',
#  'CME_F58.csv',
#  'CME_F59.csv',
#  'CME_FC1.csv',
#  'CME_FC2.csv',
#  'CME_FC3.csv',
#  'CME_FC4.csv',
#  'CME_FC5.csv',
#  'CME_FC6.csv',
#  'CME_FC7.csv',
#  'CME_FDM1.csv',
#  'CME_FDM10.csv',
#  'CME_FDM2.csv',
#  'CME_FDM3.csv',
#  'CME_FDM4.csv',
#  'CME_FDM5.csv',
#  'CME_FDM6.csv',
#  'CME_FDM7.csv',
#  'CME_FDM8.csv',
#  'CME_FDM9.csv',
#  'CME_FF1.csv',
#  'CME_FF10.csv',
#  'CME_FF11.csv',
#  'CME_FF12.csv',
#  ...]

# %%
pwd
# Out:
# 'C:\\Users\\alexb\\Documents\\class\\globaltrade\\alex'
